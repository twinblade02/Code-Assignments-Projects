# %% [markdown]
# # Chapter 5  Categorizing and Tagging Words
#
# Read through the chapter, completing the "Your Turn" activities and exercises below for each section.

# %% [markdown]
# ## Section 1 - Using a Tagger

# %% [markdown]
# **Your Turn:**
# Many words, like ski and race, can be used as nouns or verbs with no difference in pronunciation. Can you think of others? Hint: think of a commonplace object and try to put the word to before it to see if it can also be a verb, or think of an action and try to put the before it to see if it can also be a noun. Now make up a sentence with both uses of this word, and run the POS-tagger on this sentence.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import nltk
text1 = nltk.word_tokenize("I need some space to garage my cars")
text2 = nltk.word_tokenize("I require a place to build the garage")
text3 = nltk.word_tokenize("I will garage my car in the garage")
nltk.pos_tag(text1)
nltk.pos_tag(text2)
nltk.pos_tag(text3)
# Out:
# [('I', 'PRP'),
#  ('need', 'VBP'),
#  ('some', 'DT'),
#  ('space', 'NN'),
#  ('to', 'TO'),
#  ('garage', 'VB'),
#  ('my', 'PRP$'),
#  ('cars', 'NNS')]
# [('I', 'PRP'),
#  ('require', 'VBP'),
#  ('a', 'DT'),
#  ('place', 'NN'),
#  ('to', 'TO'),
#  ('build', 'VB'),
#  ('the', 'DT'),
#  ('garage', 'NN')]
# [('I', 'PRP'),
#  ('will', 'MD'),
#  ('garage', 'VB'),
#  ('my', 'PRP$'),
#  ('car', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('garage', 'NN')]

# %% [markdown]
# ## Section 2 - Tagged Corpora

# %% [markdown]
# **Your Turn:**
# Given the list of past participles produced by `list(cfd2['VBN'])`, try to collect a list of all the word-tag pairs that immediately precede items in that list.
#
# *Note that there is a typo in the book exercise, it should be `VBN` not `VN`.  Also, this is a challenging exercise.  In the code below, I've tried to make it more understandable by using a loop instead of a list comprehension.  Feel free to use the starter code or replace it with your own solution*.

# %%
'''import nltk
wsj = nltk.corpus.treebank.tagged_words()
cfd2 = nltk.ConditionalFreqDist((tag, word) for (word, tag) in wsj)
participles = list(cfd2['VBN'])
prior_list = [] # list to hold the word-tag pairs that immediately precede items in that list
for w in participles: # for each word in the list
    idx1=wsj.index((w, 'VBN'))  # find the integer location of the word/tag tuple in the corpus
    # prior_wt = wsj[??] retrieve the prior word by replacing ?? with the index of the prior word/tag pair
    # append to the word/tag pair to the list declared above
print(prior_list)'''

# %%
# using wsj corpus
wsj = nltk.corpus.treebank.tagged_words()
cfd = nltk.ConditionalFreqDist((tag,word) for (word,tag) in wsj)
participles = list(cfd['VBN'])
# [w for w in cfd.conditions() if 'VBD' in cfd[w]] - this and the previous cell yield the same result
prior = []
for w in participles:
    idx1 = wsj.index((w,'VBN'))
    word_tags = wsj[idx1-1]
    prior.append((word_tags, wsj[idx1]))
prior

# Con: Code takes very long to run [about 10 minutes without hardware acceleration]
# Out:
# [(('was', 'VBD'), ('named', 'VBN')),
#  (('once', 'RB'), ('used', 'VBN')),
#  (('has', 'VBZ'), ('caused', 'VBN')),
#  (('workers', 'NNS'), ('exposed', 'VBN')),
#  (('were', 'VBD'), ('reported', 'VBN')),
#  (('and', 'CC'), ('replaced', 'VBN')),
#  (('were', 'VBD'), ('sold', 'VBN')),
#  (('have', 'VBP'), ('died', 'VBN')),
#  (('the', 'DT'), ('expected', 'VBN')),
#  (('recently', 'RB'), ('diagnosed', 'VBN')),
#  (('workers', 'NNS'), ('studied', 'VBN')),
#  (('Western', 'JJ'), ('industrialized', 'VBN')),
#  (('is', 'VBZ'), ('owned', 'VBN')),
#  ((',', ','), ('found', 'VBN')),
#  (('are', 'VBP'), ('classified', 'VBN')),
#  (('easily', 'RB'), ('rejected', 'VBN')),
#  (('be', 'VB'), ('outlawed', 'VBN')),
#  (('the', 'DT'), ('imported', 'VBN')),
#  (('funds', 'NNS'), ('tracked', 'VBN')),
#  (('are', 'VBP'), ('thought', 'VBN')),
#  (('are', 'VBP'), ('considered', 'VBN')),
#  (('was', 'VBD'), ('elected', 'VBN')),
#  ((',', ','), ('based', 'VBN')),
#  (("n't", 'RB'), ('lifted', 'VBN')),
#  (('is', 'VBZ'), ('ensnarled', 'VBN')),
#  (('has', 'VBZ'), ('voted', 'VBN')),
#  (('had', 'VBD'), ('been', 'VBN')),
#  (('was', 'VBD'), ('held', 'VBN')),
#  (('are', 'VBP'), ('banned', 'VBN')),
#  (('the', 'DT'), ('renovated', 'VBN')),
#  (('of', 'IN'), ('prolonged', 'VBN')),
#  (('has', 'VBZ'), ('recorded', 'VBN')),
#  (("'s", 'POS'), ('accumulated', 'VBN')),
#  (('has', 'VBZ'), ('offered', 'VBN')),
#  (('have', 'VBP'), ('become', 'VBN')),
#  (('its', 'PRP$'), ('guaranteed', 'VBN')),
#  (('has', 'VBZ'), ('proposed', 'VBN')),
#  (('forecasts', 'NNS'), ('related', 'VBN')),
#  (('and', 'CC'), ('improved', 'VBN')),
#  (('also', 'RB'), ('worried', 'VBN')),
#  (('less', 'RBR'), ('cluttered', 'VBN')),
#  (('an', 'DT'), ('expedited', 'VBN')),
#  ((',', ','), ('retired', 'VBN')),
#  (('was', 'VBD'), ('ordered', 'VBN')),
#  (('rates', 'NNS'), ('collected', 'VBN')),
#  (('ever', 'RB'), ('required', 'VBN')),
#  (('have', 'VBP'), ('received', 'VBN')),
#  (('have', 'VBP'), ('moved', 'VBN')),
#  (('be', 'VB'), ('determined', 'VBN')),
#  (('collections', 'NNS'), ('made', 'VBN')),
#  (('have', 'VBP'), ('changed', 'VBN')),
#  (('was', 'VBD'), ('completed', 'VBN')),
#  (('a', 'DT'), ('disputed', 'VBN')),
#  (('be', 'VB'), ('refunded', 'VBN')),
#  (('has', 'VBZ'), ('estimated', 'VBN')),
#  ((',', ','), ('compared', 'VBN')),
#  ((',', ','), ('located', 'VBN')),
#  (('Documents', 'NNS'), ('filed', 'VBN')),
#  (('is', 'VBZ'), ('scrapped', 'VBN')),
#  (('were', 'VBD'), ('anticipated', 'VBN')),
#  (('supercomputers', 'NNS'), ('priced', 'VBN')),
#  (('been', 'VBN'), ('set', 'VBN')),
#  (('has', 'VBZ'), ('applied', 'VBN')),
#  (('it', 'PRP'), ('existed', 'VBN')),
#  (('have', 'VB'), ('incurred', 'VBN')),
#  (('be', 'VB'), ('reached', 'VBN')),
#  (('*-25', '-NONE-'), ('Regarded', 'VBN')),
#  (('was', 'VBD'), ('paid', 'VBN')),
#  (('prosecutors', 'NNS'), ('trained', 'VBN')),
#  (('has', 'VBZ'), ('instituted', 'VBN')),
#  (('has', 'VBZ'), ('vowed', 'VBN')),
#  (('are', 'VBP'), ('deemed', 'VBN')),
#  ((',', ','), ('combined', 'VBN')),
#  (('be', 'VB'), ('removed', 'VBN')),
#  (('still', 'RB'), ('concerned', 'VBN')),
#  (('have', 'VBP'), ('complained', 'VBN')),
#  (('an', 'DT'), ('accelerated', 'VBN')),
#  (('is', 'VBZ'), ('believed', 'VBN')),
#  (('been', 'VBN'), ('called', 'VBN')),
#  (('be', 'VB'), ('solved', 'VBN')),
#  (('debt', 'NN'), ('forgiven', 'VBN')),
#  (('were', 'VBD'), ('launched', 'VBN')),
#  (('was', 'VBD'), ('built', 'VBN')),
#  (('convertible', 'JJ'), ('preferred', 'VBN')),
#  (('be', 'VB'), ('raised', 'VBN')),
#  (('fields', 'NNS'), ('scheduled', 'VBN')),
#  (('be', 'VB'), ('brought', 'VBN')),
#  (('gradually', 'RB'), ('increased', 'VBN')),
#  (('were', 'VBD'), ('developed', 'VBN')),
#  (('group', 'NN'), ('led', 'VBN')),
#  (('has', 'VBZ'), ('approved', 'VBN')),
#  (("n't", 'RB'), ('produced', 'VBN')),
#  (('were', 'VBD'), ('denied', 'VBN')),
#  (('had', 'VBD'), ('requested', 'VBN')),
#  ((',', ','), ('covered', 'VBN')),
#  (('watches', 'NNS'), ('assembled', 'VBN')),
#  (('is', 'VBZ'), ('achieved', 'VBN')),
#  (('and', 'CC'), ('maintained', 'VBN')),
#  (('has', 'VBZ'), ('left', 'VBN')),
#  (('*-1', '-NONE-'), ('assisted', 'VBN')),
#  (('were', 'VBD'), ('placed', 'VBN')),
#  (('was', 'VBD'), ('put', 'VBN')),
#  (('return', 'NN'), ('linked', 'VBN')),
#  (('are', 'VBP'), ('designed', 'VBN')),
#  (('have', 'VBP'), ('boosted', 'VBN')),
#  (('amount', 'NN'), ('issued', 'VBN')),
#  (('pharmaceuticals', 'NNS'), ('incorporated', 'VBN')),
#  ((',', ','), ('advertised', 'VBN')),
#  (('previously', 'RB'), ('announced', 'VBN')),
#  (('publicly', 'RB'), ('traded', 'VBN')),
#  (('or', 'CC'), ('registered', 'VBN')),
#  (('has', 'VBZ'), ('ranged', 'VBN')),
#  (('be', 'VB'), ('capped', 'VBN')),
#  (('has', 'VBZ'), ('kicked', 'VBN')),
#  (('narrowly', 'RB'), ('focused', 'VBN')),
#  (('a', 'DT'), ('fixed', 'VBN')),
#  (('*RNR*-1', '-NONE-'), ('listed', 'VBN')),
#  (('have', 'VBP'), ('turned', 'VBN')),
#  (('have', 'VBP'), ('scrambled', 'VBN')),
#  (('have', 'VBP'), ('outpaced', 'VBN')),
#  (('get', 'VB'), ('burned', 'VBN')),
#  (('were', 'VBD'), ('clobbered', 'VBN')),
#  (('have', 'VBP'), ('climbed', 'VBN')),
#  (('partially', 'RB'), ('closed', 'VBN')),
#  (('have', 'VBP'), ('skyrocketed', 'VBN')),
#  (('has', 'VBZ'), ('surged', 'VBN')),
#  (('been', 'VBN'), ('targeted', 'VBN')),
#  (('play', 'NN'), ('tied', 'VBN')),
#  (('fully', 'RB'), ('invested', 'VBN')),
#  (('have', 'VBP'), ('jumped', 'VBN')),
#  (('very', 'RB'), ('alarmed', 'VBN')),
#  (('newly', 'RB'), ('fattened', 'VBN')),
#  (('viewpoint', 'NN'), ('cast', 'VBN')),
#  (('are', 'VBP'), ('repaid', 'VBN')),
#  (('has', 'VBZ'), ('permitted', 'VBN')),
#  (('be', 'VB'), ('crippled', 'VBN')),
#  (('was', 'VBD'), ('lent', 'VBN')),
#  (('*', '-NONE-'), ('amended', 'VBN')),
#  (('has', 'VBZ'), ('settled', 'VBN')),
#  (('for', 'IN'), ('manufactured', 'VBN')),
#  (('have', 'VB'), ('fallen', 'VBN')),
#  (('were', 'VBD'), ('adjusted', 'VBN')),
#  (('has', 'VBZ'), ('failed', 'VBN')),
#  (('closely', 'RB'), ('watched', 'VBN')),
#  (('those', 'DT'), ('intended', 'VBN')),
#  (('*-3', '-NONE-'), ('helped', 'VBN')),
#  (('contracts', 'NNS'), ('awarded', 'VBN')),
#  (('is', 'VBZ'), ('spent', 'VBN')),
#  (('data', 'NNS'), ('provided', 'VBN')),
#  ((',', ','), ('coupled', 'VBN')),
#  (('through', 'IN'), ('broken', 'VBN')),
#  (('is', 'VBZ'), ('rooted', 'VBN')),
#  (('are', 'VBP'), ('written', 'VBN')),
#  (('is', 'VBZ'), ('played', 'VBN')),
#  (('even', 'JJ'), ('welcomed', 'VBN')),
#  ((',', ','), ('rationed', 'VBN')),
#  (('are', 'VBP'), ('assigned', 'VBN')),
#  (('dormitory', 'NN'), ('run', 'VBN')),
#  (('has', 'VBZ'), ('opened', 'VBN')),
#  (('to', 'TO'), ('designated', 'VBN')),
#  (('was', 'VBD'), ('carried', 'VBN')),
#  (('other', 'JJ'), ('surveyed', 'VBN')),
#  (('was', 'VBD'), ('confirmed', 'VBN')),
#  (('were', 'VBD'), ('tested', 'VBN')),
#  (('time', 'NN'), ('had', 'VBN')),
#  (('financially', 'RB'), ('strapped', 'VBN')),
#  (('be', 'VB'), ('twinned', 'VBN')),
#  (('*', '-NONE-'), ('planned', 'VBN')),
#  (('be', 'VB'), ('operated', 'VBN')),
#  (('was', 'VBD'), ('painted', 'VBN')),
#  (('plus', 'CC'), ('accrued', 'VBN')),
#  (('be', 'VB'), ('swapped', 'VBN')),
#  (('already', 'RB'), ('laid', 'VBN')),
#  (('been', 'VBN'), ('obsessed', 'VBN')),
#  (('has', 'VBZ'), ('revived', 'VBN')),
#  (('has', 'VBZ'), ('prepared', 'VBN')),
#  (('highly', 'RB'), ('romanticized', 'VBN')),
#  (('*-2', '-NONE-'), ('Filmed', 'VBN')),
#  (('Avenue', 'NNP'), ('populated', 'VBN')),
#  (('the', 'DT'), ('condemned', 'VBN')),
#  (('is', 'VBZ'), ('given', 'VBN')),
#  (('been', 'VBN'), ('murdered', 'VBN')),
#  (('has', 'VBZ'), ('managed', 'VBN')),
#  (('*-2', '-NONE-'), ('viewed', 'VBN')),
#  (('be', 'VB'), ('executed', 'VBN')),
#  (('*', '-NONE-'), ('presented', 'VBN')),
#  (('head', 'NN'), ('chopped', 'VBN')),
#  (('is', 'VBZ'), ('taken', 'VBN')),
#  (('been', 'VBN'), ('worked', 'VBN')),
#  (('have', 'VBP'), ('speculated', 'VBN')),
#  (('has', 'VBZ'), ('come', 'VBN')),
#  (('contests', 'NNS'), ('scattered', 'VBN')),
#  (('are', 'VBP'), ('prompted', 'VBN')),
#  (('a', 'DT'), ('convicted', 'VBN')),
#  (("'s", 'VBZ'), ('caught', 'VBN')),
#  (('*-2', '-NONE-'), ('Stung', 'VBN')),
#  (('has', 'VBZ'), ('opposed', 'VBN')),
#  (('has', 'VBZ'), ('refused', 'VBN')),
#  (('has', 'VBZ'), ('blamed', 'VBN')),
#  (('Monticello', 'NNP'), ('superimposed', 'VBN')),
#  (('have', 'VBP'), ('nurtured', 'VBN')),
#  (('advertisements', 'NNS'), ('created', 'VBN')),
#  (('were', 'VBD'), ('attracted', 'VBN')),
#  (('be', 'VB'), ('interrogated', 'VBN')),
#  (('for', 'IN'), ('accused', 'VBN')),
#  (('was', 'VBD'), ('introduced', 'VBN')),
#  (('have', 'VBP'), ('grown', 'VBN')),
#  (('has', 'VBZ'), ('gotten', 'VBN')),
#  (('of', 'IN'), ('rusted', 'VBN')),
#  (('fraud', 'NN'), ('involved', 'VBN')),
#  (('has', 'VBZ'), ('responded', 'VBN')),
#  (('was', 'VBD'), ('cleaned', 'VBN')),
#  (('were', 'VBD'), ('dumped', 'VBN')),
#  (('are', 'VBP'), ('quoted', 'VBN')),
#  ((',', ','), ('asked', 'VBN')),
#  (('have', 'VBP'), ('pursued', 'VBN')),
#  (('be', 'VB'), ('knitted', 'VBN')),
#  (('have', 'VBP'), ('tripled', 'VBN')),
#  ((',', ','), ('known', 'VBN')),
#  (('*-2', '-NONE-'), ('spurred', 'VBN')),
#  (('had', 'VBD'), ('seen', 'VBN')),
#  (('is', 'VBZ'), ('passed', 'VBN')),
#  (('*-2', '-NONE-'), ('Confronted', 'VBN')),
#  (('had', 'VBD'), ('gone', 'VBN')),
#  (('was', 'VBD'), ('fired', 'VBN')),
#  (('and', 'CC'), ('prosecuted', 'VBN')),
#  (('was', 'VBD'), ('treated', 'VBN')),
#  (('has', 'VBZ'), ('enhanced', 'VBN')),
#  (('study', 'NN'), ('released', 'VBN')),
#  (('greatly', 'RB'), ('inflated', 'VBN')),
#  (('has', 'VBZ'), ('surfaced', 'VBN')),
#  (('has', 'VBZ'), ('posted', 'VBN')),
#  (('has', 'VBZ'), ('educated', 'VBN')),
#  (('had', 'VBD'), ('faded', 'VBN')),
#  (('*-1', '-NONE-'), ('stabbed', 'VBN')),
#  (('was', 'VBD'), ('chosen', 'VBN')),
#  (('ever', 'RB'), ('learned', 'VBN')),
#  (("n't", 'RB'), ('tried', 'VBN')),
#  (('was', 'VBD'), ('discovered', 'VBN')),
#  (('was', 'VBD'), ('dismissed', 'VBN')),
#  (('was', 'VBD'), ('crowded', 'VBN')),
#  (("'ve", 'VBP'), ('got', 'VBN')),
#  (('being', 'VBG'), ('overused', 'VBN')),
#  (('have', 'VB'), ('expunged', 'VBN')),
#  (('were', 'VBD'), ('interviewed', 'VBN')),
#  (('have', 'VBP'), ('wanted', 'VBN')),
#  (("n't", 'RB'), ('aimed', 'VBN')),
#  (("n't", 'RB'), ('replicated', 'VBN')),
#  (('*', '-NONE-'), ('referred', 'VBN')),
#  (('*T*-107', '-NONE-'), ('matched', 'VBN')),
#  (('subskill', 'NN'), ('measured', 'VBN')),
#  (('be', 'VB'), ('continued', 'VBN')),
#  (('privately', 'RB'), ('funded', 'VBN')),
#  (('is', 'VBZ'), ('threatened', 'VBN')),
#  (('became', 'VBD'), ('embroiled', 'VBN')),
#  (('has', 'VBZ'), ('hampered', 'VBN')),
#  (('have', 'VBP'), ('withdrawn', 'VBN')),
#  (('has', 'VBZ'), ('assured', 'VBN')),
#  (('have', 'VBP'), ('charged', 'VBN')),
#  (('be', 'VB'), ('judged', 'VBN')),
#  (('become', 'VBN'), ('polarized', 'VBN')),
#  (('.', '.'), ('Rekindled', 'VBN')),
#  (('has', 'VBZ'), ('agreed', 'VBN')),
#  (('an', 'DT'), ('indicated', 'VBN')),
#  (('have', 'VBP'), ('returned', 'VBN')),
#  (('has', 'VBZ'), ('signed', 'VBN')),
#  (('be', 'VB'), ('acquired', 'VBN')),
#  (('losses', 'NNS'), ('associated', 'VBN')),
#  (("'s", 'POS'), ('lost', 'VBN')),
#  (('has', 'VBZ'), ('redeemed', 'VBN')),
#  (('quarter', 'NN'), ('ended', 'VBN')),
#  (('is', 'VBZ'), ('protected', 'VBN')),
#  (('have', 'VBP'), ('argued', 'VBN')),
#  (('has', 'VBZ'), ('heard', 'VBN')),
#  (('forms', 'NNS'), ('sent', 'VBN')),
#  (('include', 'VB'), ('alleged', 'VBN')),
#  (('had', 'VBD'), ('retained', 'VBN')),
#  ((',', ','), ('chaired', 'VBN')),
#  (('are', 'VBP'), ('prohibited', 'VBN')),
#  (('being', 'VBG'), ('initiated', 'VBN')),
#  (('correspondence', 'NN'), ('mailed', 'VBN')),
#  (('have', 'VBP'), ('obtained', 'VBN')),
#  (('are', 'VBP'), ('relegated', 'VBN')),
#  (('was', 'VBD'), ('employed', 'VBN')),
#  (('RULING', 'NN'), ('UPHELD', 'VBN')),
#  (('rule', 'NN'), ('adopted', 'VBN')),
#  (('had', 'VBD'), ('sparked', 'VBN')),
#  (('been', 'VBN'), ('killed', 'VBN')),
#  (('master', 'NN'), ('appointed', 'VBN')),
#  (('never', 'RB'), ('exhibited', 'VBN')),
#  (('is', 'VBZ'), ('empowered', 'VBN')),
#  (('has', 'VBZ'), ('served', 'VBN')),
#  (("n't", 'RB'), ('disclosed', 'VBN')),
#  (('historically', 'RB'), ('accepted', 'VBN')),
#  (('also', 'RB'), ('fueled', 'VBN')),
#  (("n't", 'RB'), ('decided', 'VBN')),
#  (('companies', 'NNS'), ('contacted', 'VBN')),
#  (('was', 'VBD'), ('formed', 'VBN')),
#  (('*', '-NONE-'), ('compiled', 'VBN')),
#  (('.', '.'), ('Guaranteed', 'VBN')),
#  (('*', '-NONE-'), ('Related', 'VBN')),
#  (('poorly', 'RB'), ('positioned', 'VBN')),
#  (('*-1', '-NONE-'), ('buoyed', 'VBN')),
#  (('has', 'VBZ'), ('kept', 'VBN')),
#  (('been', 'VBN'), ('locked', 'VBN')),
#  (('been', 'VBN'), ('offset', 'VBN')),
#  (('not', 'RB'), ('convinced', 'VBN')),
#  (('temporarily', 'RB'), ('mollified', 'VBN')),
#  (('issue', 'NN'), ('valued', 'VBN')),
#  (('be', 'VB'), ('rolled', 'VBN')),
#  (('.', '.'), ('Estimated', 'VBN')),
#  (('being', 'VBG'), ('flooded', 'VBN')),
#  (('``', '``'), ('pleased', 'VBN')),
#  (('*-2', '-NONE-'), ('Founded', 'VBN')),
#  (('has', 'VBZ'), ('alienated', 'VBN')),
#  (('was', 'VBD'), ('chastised', 'VBN')),
#  (('was', 'VBD'), ('printed', 'VBN')),
#  (('was', 'VBD'), ('portrayed', 'VBN')),
#  (('be', 'VB'), ('relied', 'VBN')),
#  (('on', 'IN'), ('recycled', 'VBN')),
#  (('*-1', '-NONE-'), ('Asked', 'VBN')),
#  (('be', 'VB'), ('scared', 'VBN')),
#  (('been', 'VBN'), ('handled', 'VBN')),
#  (('been', 'VBN'), ('serviced', 'VBN')),
#  (('cars', 'NNS'), ('damaged', 'VBN')),
#  (('*-2', '-NONE-'), ('Developed', 'VBN')),
#  (('*-2', '-NONE-'), ('pressed', 'VBN')),
#  (('be', 'VB'), ('allocated', 'VBN')),
#  (('being', 'VBG'), ('converted', 'VBN')),
#  (('still', 'RB'), ('mired', 'VBN')),
#  (('temporarily', 'RB'), ('barred', 'VBN')),
#  (('had', 'VBD'), ('said', 'VBN')),
#  (('be', 'VB'), ('equipped', 'VBN')),
#  (('vehicles', 'NNS'), ('classed', 'VBN')),
#  (('be', 'VB'), ('depressed', 'VBN')),
#  (('them', 'PRP'), ('installed', 'VBN')),
#  (('have', 'VBP'), ('met', 'VBN')),
#  (('1,000', 'CD'), ('enclosed', 'VBN')),
#  (('has', 'VBZ'), ('dropped', 'VBN')),
#  (('been', 'VBN'), ('hit', 'VBN')),
#  (('The', 'DT'), ('reduced', 'VBN')),
#  (('wines', 'NN'), ('limited', 'VBN')),
#  (('so', 'RB'), ('perceived', 'VBN')),
#  ((',', ','), ('rarefied', 'VBN')),
#  (('have', 'VBP'), ('zoomed', 'VBN')),
#  (('have', 'VB'), ('soared', 'VBN')),
#  (('have', 'VB'), ('commanded', 'VBN')),
#  (('almost', 'RB'), ('exhausted', 'VBN')),
#  (('was', 'VBD'), ('shipped', 'VBN')),
#  (('was', 'VBD'), ('spread', 'VBN')),
#  (('is', 'VBZ'), ('talked', 'VBN')),
#  (('get', 'VB'), ('excited', 'VBN')),
#  (('is', 'VBZ'), ('overpriced', 'VBN')),
#  (('be', 'VB'), ('forced', 'VBN')),
#  (('have', 'VBP'), ('moderated', 'VBN')),
#  (('the', 'DT'), ('stated', 'VBN')),
#  (('has', 'VBZ'), ('shown', 'VBN')),
#  (('was', 'VBD'), ('described', 'VBN')),
#  (('be', 'VB'), ('divided', 'VBN')),
#  (('was', 'VBD'), ('declared', 'VBN')),
#  (('be', 'VB'), ('exercised', 'VBN')),
#  (('be', 'VB'), ('postponed', 'VBN')),
#  (('be', 'VB'), ('rescheduled', 'VBN')),
#  (('be', 'VB'), ('auctioned', 'VBN')),
#  (('of', 'IN'), ('frozen', 'VBN')),
#  (('were', 'VBD'), ('disappointed', 'VBN')),
#  (("n't", 'RB'), ('eliminated', 'VBN')),
#  (('has', 'VBZ'), ('clamped', 'VBN')),
#  (("n't", 'RB'), ('surprised', 'VBN')),
#  (('price', 'NN'), ('cited', 'VBN')),
#  (('high-yield', 'JJ'), ('subordinated', 'VBN')),
#  (('has', 'VBZ'), ('collapsed', 'VBN')),
#  (("n't", 'RB'), ('allowed', 'VBN')),
#  (('has', 'VBZ'), ('followed', 'VBN')),
#  (('is', 'VBZ'), ('interested', 'VBN')),
#  (('most', 'JJS'), ('purchased', 'VBN')),
#  (('have', 'VBP'), ('escalated', 'VBN')),
#  (('well', 'RB'), ('stoked', 'VBN')),
#  (('highly', 'RB'), ('publicized', 'VBN')),
#  (("'ve", 'VBP'), ('identified', 'VBN')),
#  (("n't", 'RB'), ('clarified', 'VBN')),
#  (('have', 'VBP'), ('crossed', 'VBN')),
#  (('be', 'VB'), ('milked', 'VBN')),
#  (('have', 'VBP'), ('financed', 'VBN')),
#  (('vertically', 'RB'), ('integrated', 'VBN')),
#  (('often', 'RB'), ('performed', 'VBN')),
#  (('be', 'VB'), ('assumed', 'VBN')),
#  (('have', 'VBP'), ('competed', 'VBN')),
#  (('having', 'VBG'), ('borrowed', 'VBN')),
#  (('were', 'VBD'), ('squeezed', 'VBN')),
#  (('emphasis', 'NN'), ('switched', 'VBN')),
#  (('has', 'VBZ'), ('cultivated', 'VBN')),
#  (('be', 'VB'), ('tailored', 'VBN')),
#  (('help', 'VB'), ('troubled', 'VBN')),
#  (('is', 'VBZ'), ('triggered', 'VBN')),
#  (('was', 'VBD'), ('needed', 'VBN')),
#  (('prices', 'NNS'), ('synchronized', 'VBN')),
#  (('publicly', 'RB'), ('expressed', 'VBN')),
#  (('have', 'VB'), ('done', 'VBN')),
#  (('be', 'VB'), ('discussed', 'VBN')),
#  (('is', 'VBZ'), ('regulated', 'VBN')),
#  (('ropes', 'NNS'), ('attached', 'VBN')),
#  (('longer', 'RBR'), ('rung', 'VBN')),
#  (('are', 'VBP'), ('started', 'VBN')),
#  (('*-2', '-NONE-'), ('muffled', 'VBN')),
#  (('Totally', 'RB'), ('absorbed', 'VBN')),
#  ((',', ','), ('mounted', 'VBN')),
#  (('``', '``'), ('filled', 'VBN')),
#  (('so', 'RB'), ('fed', 'VBN')),
#  (('to', 'TO'), ('mixed', 'VBN')),
#  (('be', 'VB'), ('drawn', 'VBN')),
#  (('have', 'VBP'), ('entered', 'VBN')),
#  ((',', ','), ('founded', 'VBN')),
#  (("''", "''"), ('remarked', 'VBN')),
#  (('Solihull', 'NNP'), ('observed', 'VBN')),
#  (('be', 'VB'), ('desired', 'VBN')),
#  (('badly', 'RB'), ('dressed', 'VBN')),
#  ((',', ','), ('decorated', 'VBN')),
#  (('Investors', 'NNS'), ('unsettled', 'VBN')),
#  (('sometimes', 'RB'), ('risen', 'VBN')),
#  (('*', '-NONE-'), ('Put', 'VBN')),
#  (('a', 'DT'), ('sustained', 'VBN')),
#  (('always', 'RB'), ('tanked', 'VBN')),
#  (('the', 'DT'), ('renewed', 'VBN')),
#  (('microphone', 'NN'), ('invented', 'VBN')),
#  ((',', ','), ('infringed', 'VBN')),
#  (('has', 'VBZ'), ('hired', 'VBN')),
#  (('recently', 'RB'), ('afflicted', 'VBN')),
#  (('have', 'VBP'), ('deteriorated', 'VBN')),
#  (('be', 'VB'), ('codified', 'VBN')),
#  (('have', 'VB'), ('gained', 'VBN')),
#  (('had', 'VBD'), ('discarded', 'VBN')),
#  (('have', 'VBP'), ('pointed', 'VBN')),
#  (("n't", 'RB'), ('loaded', 'VBN')),
#  (('continually', 'RB'), ('defined', 'VBN')),
#  (('were', 'VBD'), ('expelled', 'VBN')),
#  (('were', 'VBD'), ('suspended', 'VBN')),
#  (('were', 'VBD'), ('fined', 'VBN')),
#  (('inaccurately', 'RB'), ('represented', 'VBN')),
#  (('had', 'VBD'), ('consented', 'VBN')),
#  (('funds', 'NNS'), ('owed', 'VBN')),
#  (('*-2', '-NONE-'), ('Reached', 'VBN')),
#  (('rapidly', 'RB'), ('rectified', 'VBN')),
#  (('*', '-NONE-'), ('noted', 'VBN')),
#  (('actively', 'RB'), ('engaged', 'VBN')),
#  (('are', 'VBP'), ('blocked', 'VBN')),
#  (("n't", 'RB'), ('forgotten', 'VBN')),
#  (('since', 'IN'), ('tightened', 'VBN')),
#  (('have', 'VBP'), ('reaped', 'VBN')),
#  (('have', 'VBP'), ('stopped', 'VBN')),
#  (('prices', 'NNS'), ('pegged', 'VBN')),
#  (('measure', 'NN'), ('backed', 'VBN')),
#  (('was', 'VBD'), ('enacted', 'VBN')),
#  (('have', 'VBP'), ('sought', 'VBN')),
#  (('lately', 'RB'), ('touted', 'VBN')),
#  (("n't", 'RB'), ('faced', 'VBN')),
#  (('were', 'VBD'), ('negotiated', 'VBN')),
#  (('*-2', '-NONE-'), ('Given', 'VBN')),
#  (('That', 'DT'), ('impressed', 'VBN')),
#  (('has', 'VBZ'), ('engineered', 'VBN')),
#  (('and', 'CC'), ('hurt', 'VBN')),
#  (('have', 'VBP'), ('diversified', 'VBN')),
#  (('an', 'DT'), ('expanded', 'VBN')),
#  (('are', 'VBP'), ('committed', 'VBN')),
#  (('already', 'RB'), ('provoked', 'VBN')),
#  (('sharply', 'RB'), ('confined', 'VBN')),
#  (('was', 'VBD'), ('stripped', 'VBN')),
#  (('been', 'VBN'), ('reallocated', 'VBN')),
#  (('apparently', 'RB'), ('instructed', 'VBN')),
#  (('initially', 'RB'), ('drafted', 'VBN')),
#  (('be', 'VB'), ('repaired', 'VBN')),
#  (('*-1', '-NONE-'), ('upset', 'VBN')),
#  (('be', 'VB'), ('altered', 'VBN')),
#  (('were', 'VBD'), ('corrected', 'VBN')),
#  (('has', 'VBZ'), ('promised', 'VBN')),
#  (('has', 'VBZ'), ('proved', 'VBN')),
#  (('poorly', 'RB'), ('understood', 'VBN')),
#  (('is', 'VBZ'), ('composed', 'VBN')),
#  (('intimately', 'RB'), ('connected', 'VBN')),
#  (('highly', 'RB'), ('regarded', 'VBN')),
#  (('being', 'VBG'), ('robbed', 'VBN')),
#  (('be', 'VB'), ('deprived', 'VBN')),
#  (('by', 'IN'), ('organized', 'VBN')),
#  (('be', 'VB'), ('impaired', 'VBN')),
#  (('sharply', 'RB'), ('diminished', 'VBN')),
#  (('the', 'DT'), ('added', 'VBN')),
#  (('was', 'VBD'), ('advised', 'VBN')),
#  (('are', 'VBP'), ('mentioned', 'VBN')),
#  (('be', 'VB'), ('answered', 'VBN')),
#  ((',', ','), ('oriented', 'VBN')),
#  (('has', 'VBZ'), ('contributed', 'VBN')),
#  (('is', 'VBZ'), ('dominated', 'VBN')),
#  (('have', 'VBP'), ('pushed', 'VBN')),
#  (('INTERBANK', 'NN'), ('OFFERED', 'VBN')),
#  ((':', ':'), ('Posted', 'VBN')),
#  (('.', '.'), ('Annualized', 'VBN')),
#  (('have', 'VB'), ('clashed', 'VBN')),
#  (('has', 'VBZ'), ('enjoyed', 'VBN')),
#  (('Not', 'RB'), ('included', 'VBN')),
#  ((',', ','), ('recruited', 'VBN')),
#  (('was', 'VBD'), ('rumored', 'VBN')),
#  (('widely', 'RB'), ('respected', 'VBN')),
#  (('``', '``'), ('Provided', 'VBN')),
#  (('prerogatives', 'NNS'), ('specified', 'VBN')),
#  (('is', 'VBZ'), ('predicated', 'VBN')),
#  (('officially', 'RB'), ('endorsed', 'VBN')),
#  (('broadly', 'RB'), ('construed', 'VBN')),
#  (('not', 'RB'), ('supported', 'VBN')),
#  (('be', 'VB'), ('read', 'VBN')),
#  (('year', 'NN'), ('contained', 'VBN')),
#  (('been', 'VBN'), ('nominated', 'VBN')),
#  (('being', 'VBG'), ('wasted', 'VBN')),
#  (('some', 'DT'), ('favored', 'VBN')),
#  (('been', 'VBN'), ('disapproved', 'VBN')),
#  (('had', 'VBD'), ('ratified', 'VBN')),
#  (('is', 'VBZ'), ('characterized', 'VBN')),
#  (('have', 'VB'), ('won', 'VBN')),
#  (('be', 'VB'), ('entrusted', 'VBN')),
#  (('``', '``'), ('mortgaged', 'VBN')),
#  (('the', 'DT'), ('reclaimed', 'VBN')),
#  (('less', 'JJR'), ('parched', 'VBN')),
#  (('partly', 'RB'), ('cushioned', 'VBN')),
#  (('*-1', '-NONE-'), ('shut', 'VBN')),
#  (('An', 'DT'), ('attempted', 'VBN')),
#  (('*-1', '-NONE-'), ('torn', 'VBN')),
#  (('sometimes', 'RB'), ('staid', 'VBN')),
#  (('had', 'VBD'), ('flirted', 'VBN')),
#  (('empire', 'NN'), ('abandoned', 'VBN')),
#  (('had', 'VBD'), ('stepped', 'VBN')),
#  (('edition', 'NN'), ('headlined', 'VBN')),
#  (('senior', 'JJ'), ('secured', 'VBN')),
#  (("'s", 'POS'), ('beleaguered', 'VBN')),
#  (('have', 'VBP'), ('begun', 'VBN')),
#  (('have', 'VBP'), ('plunged', 'VBN')),
#  (('``', '``'), ('missed', 'VBN')),
#  (('were', 'VBD'), ('preapproved', 'VBN')),
#  (('be', 'VB'), ('upheld', 'VBN')),
#  (('have', 'VB'), ('accounted', 'VBN')),
#  (("n't", 'RB'), ('vested', 'VBN')),
#  (('been', 'VBN'), ('shaken', 'VBN')),
#  (('the', 'DT'), ('heated', 'VBN')),
#  (('unfairly', 'RB'), ('labeled', 'VBN')),
#  (('have', 'VB'), ('exacerbated', 'VBN')),
#  (('has', 'VBZ'), ('wedded', 'VBN')),
#  (('``', '``'), ('headed', 'VBN')),
#  (("n't", 'RB'), ('curbed', 'VBN')),
#  (('Its', 'PRP$'), ('entrenched', 'VBN')),
#  (('heavily', 'RB'), ('stacked', 'VBN')),
#  (('becomes', 'VBZ'), ('frightened', 'VBN')),
#  (('and', 'CC'), ('automated', 'VBN')),
#  (('have', 'VBP'), ('earned', 'VBN')),
#  (('investors', 'NNS'), ('spooked', 'VBN')),
#  (('been', 'VBN'), ('transformed', 'VBN')),
#  (('publicity', 'NN'), ('orchestrated', 'VBN')),
#  (('been', 'VBN'), ('gored', 'VBN')),
#  (('has', 'VBZ'), ('proven', 'VBN')),
#  (('has', 'VBZ'), ('minted', 'VBN')),
#  (('relentlessly', 'RB'), ('beaten', 'VBN')),
#  (('usually', 'RB'), ('practiced', 'VBN')),
#  (('are', 'VBP'), ('implemented', 'VBN')),
#  (('be', 'VB'), ('feared', 'VBN')),
#  (('*-1', '-NONE-'), ('Left', 'VBN')),
#  (('be', 'VB'), ('cut', 'VBN')),
#  (('was', 'VBD'), ('appropriated', 'VBN')),
#  (("n't", 'RB'), ('noticed', 'VBN')),
#  (('essentially', 'RB'), ('finished', 'VBN')),
#  (('poorly', 'RB'), ('documented', 'VBN')),
#  (('changing', 'VBG'), ('colored', 'VBN')),
#  (('*-1', '-NONE-'), ('Funded', 'VBN')),
#  (('*-1', '-NONE-'), ('Concerned', 'VBN')),
#  (('is', 'VBZ'), ('marketed', 'VBN')),
#  (('is', 'VBZ'), ('echoed', 'VBN')),
#  (('be', 'VB'), ('halted', 'VBN')),
#  (('just', 'RB'), ('recouped', 'VBN')),
#  (('has', 'VBZ'), ('hunted', 'VBN')),
#  (('superconductors', 'NNS'), ('cooled', 'VBN')),
#  (('be', 'VB'), ('overcome', 'VBN')),
#  (('was', 'VBD'), ('terminated', 'VBN')),
#  (('*-1', '-NONE-'), ('Rated', 'VBN')),
#  (('are', 'VBP'), ('insured', 'VBN')),
#  (('are', 'VBP'), ('rated', 'VBN')),
#  (('has', 'VBZ'), ('looked', 'VBN')),
#  (('have', 'VB'), ('justified', 'VBN')),
#  (('from', 'IN'), ('discontinued', 'VBN')),
#  (('ratings', 'NNS'), ('lowered', 'VBN')),
#  (("'s", 'VBZ'), ('warned', 'VBN')),
#  (('are', 'VBP'), ('structured', 'VBN')),
#  (('funds', 'NNS'), ('generated', 'VBN')),
#  (('is', 'VBZ'), ('overstated', 'VBN')),
#  (('two', 'CD'), ('midsized', 'VBN')),
#  (('be', 'VB'), ('assessed', 'VBN')),
#  (('has', 'VBZ'), ('chilled', 'VBN')),
#  ((',', ','), ('hidden', 'VBN')),
#  (('be', 'VB'), ('inserted', 'VBN')),
#  (('had', 'VBD'), ('harmed', 'VBN')),
#  (('constantly', 'RB'), ('stressed', 'VBN')),
#  (('225', 'CD'), ('selected', 'VBN')),
#  (('was', 'VBD'), ('directed', 'VBN')),
#  (('also', 'RB'), ('stimulated', 'VBN')),
#  (('were', 'VBD'), ('bolstered', 'VBN')),
#  (('were', 'VBD'), ('overdone', 'VBN')),
#  (('*', '-NONE-'), ('calculated', 'VBN')),
#  (('.', '.'), ('Named', 'VBN')),
#  (('a', 'DT'), ('revised', 'VBN')),
#  (('be', 'VB'), ('attributed', 'VBN')),
#  (('is', 'VBZ'), ('conducted', 'VBN')),
#  (('were', 'VBD'), ('snapped', 'VBN')),
#  (('economists', 'NNS'), ('polled', 'VBN')),
#  (('were', 'VBD'), ('topped', 'VBN')),
#  (('easily', 'RB'), ('outdistanced', 'VBN')),
#  (('be', 'VB'), ('relaunched', 'VBN')),
#  (('a', 'DT'), ('restructured', 'VBN')),
#  (('be', 'VB'), ('repriced', 'VBN')),
#  (('been', 'VBN'), ('concluded', 'VBN')),
#  (('been', 'VBN'), ('hailed', 'VBN')),
#  (('but', 'CC'), ('despised', 'VBN')),
#  (('of', 'IN'), ('heightened', 'VBN')),
#  (('*-2', '-NONE-'), ('Used', 'VBN')),
#  (('simply', 'RB'), ('nullified', 'VBN')),
#  (('were', 'VBD'), ('puzzled', 'VBN')),
#  (('already', 'RB'), ('bought', 'VBN')),
#  (('been', 'VBN'), ('notified', 'VBN')),
#  (('was', 'VBD'), ('merged', 'VBN')),
#  (('be', 'VB'), ('delisted', 'VBN')),
#  (('are', 'VBP'), ('meant', 'VBN')),
#  (('already', 'RB'), ('own', 'VBN')),
#  (('been', 'VBN'), ('tendered', 'VBN')),
#  (('was', 'VBD'), ('singled', 'VBN')),
#  (('were', 'VBD'), ('granted', 'VBN')),
#  (('being', 'VBG'), ('felt', 'VBN')),
#  (('extremely', 'RB'), ('confused', 'VBN')),
#  (('very', 'RB'), ('complicated', 'VBN')),
#  (('was', 'VBD'), ('muted', 'VBN')),
#  (('.', '.'), ('Continued', 'VBN')),
#  (('be', 'VB'), ('split', 'VBN')),
#  (('fully', 'RB'), ('diluted', 'VBN')),
#  (('was', 'VBD'), ('magnified', 'VBN')),
#  (('be', 'VB'), ('reimbursed', 'VBN')),
#  (('remains', 'VBZ'), ('subdued', 'VBN')),
#  ((',', ','), ('controlled', 'VBN')),
#  (('be', 'VB'), ('liquidated', 'VBN')),
#  (('company', 'NN'), ('distributed', 'VBN')),
#  (('has', 'VBZ'), ('experienced', 'VBN')),
#  (('a', 'DT'), ('customized', 'VBN')),
#  (('be', 'VB'), ('extended', 'VBN')),
#  (('The', 'DT'), ('sweetened', 'VBN')),
#  (('is', 'VBZ'), ('derived', 'VBN')),
#  (('been', 'VBN'), ('averted', 'VBN')),
#  (('was', 'VBD'), ('slated', 'VBN')),
#  (('be', 'VB'), ('delivered', 'VBN')),
#  (('of', 'IN'), ('capitalized', 'VBN')),
#  (('being', 'VBG'), ('examined', 'VBN')),
#  (('the', 'DT'), ('reorganized', 'VBN')),
#  (('was', 'VBD'), ('plagued', 'VBN')),
#  (('was', 'VBD'), ('imposed', 'VBN')),
#  (('accused', 'VBD'), ('armed', 'VBN')),
#  (('was', 'VBD'), ('rigged', 'VBN')),
#  (('has', 'VBZ'), ('subpoenaed', 'VBN')),
#  (('been', 'VBN'), ('planted', 'VBN')),
#  (('has', 'VBZ'), ('told', 'VBN')),
#  (('be', 'VB'), ('centralized', 'VBN')),
#  (('have', 'VBP'), ('resulted', 'VBN')),
#  (('was', 'VBD'), ('forecast', 'VBN')),
#  (('a', 'DT'), ('fizzled', 'VBN')),
#  (('has', 'VBZ'), ('edged', 'VBN')),
#  (('really', 'RB'), ('battered', 'VBN')),
#  (('have', 'VB'), ('floated', 'VBN')),
#  (('be', 'VB'), ('spun', 'VBN')),
#  (('has', 'VBZ'), ('licensed', 'VBN')),
#  (('well', 'RB'), ('qualified', 'VBN')),
#  (('the', 'DT'), ('specialized', 'VBN')),
#  (('have', 'VBP'), ('trimmed', 'VBN')),
#  (('highly', 'RB'), ('detailed', 'VBN')),
#  (('was', 'VBD'), ('born', 'VBN')),
#  (('old', 'JJ'), ('fashioned', 'VBN')),
#  (('the', 'DT'), ('bribed', 'VBN')),
#  (('*-1', '-NONE-'), ('arrested', 'VBN')),
#  (('*-1', '-NONE-'), ('Absorbed', 'VBN')),
#  (('is', 'VBZ'), ('finalized', 'VBN')),
#  (('*-1', '-NONE-'), ('dashed', 'VBN')),
#  (('are', 'VBP'), ('omitted', 'VBN')),
#  (('recently', 'RB'), ('harvested', 'VBN')),
#  (('is', 'VBZ'), ('slowed', 'VBN')),
#  (('stockpiles', 'NNS'), ('depleted', 'VBN')),
#  (('are', 'VBP'), ('obligated', 'VBN')),
#  (('were', 'VBD'), ('compressed', 'VBN')),
#  (('were', 'VBD'), ('delayed', 'VBN')),
#  (('being', 'VBG'), ('influenced', 'VBN')),
#  (('was', 'VBD'), ('reflected', 'VBN')),
#  (('introduced', 'VBD'), ('advanced', 'VBN')),
#  (('galvanized', 'JJ'), ('coated', 'VBN')),
#  (('have', 'VBP'), ('shared', 'VBN'))]

# %% [markdown]
# ## Section 3 -  Mapping Words to Properties Using Python Dictionaries

# %% [markdown]
# **Exercise:**
# Create two dictionaries, d1 and d2, and add some entries to each. Now issue the command `d1.update(d2)`. What did this do? What might it be useful for?
#
# *Be sure to include both the code and answers to both questions.  Add additional cells if necessary*

# %%
d1 = dict({1:'This',2:'is',3:'a',4:'sentence'})
d2 = dict({1:'Add',2:'Russian',3:'Collusion'})
d1.update(d2)

print(d1)
# Out:
# {1: 'Add', 2: 'Russian', 3: 'Collusion', 4: 'sentence'}

# %% [markdown]
# #### Explanation:
# The update function joins both dictionaries together and replaces the values that have the same keys
# to the dictionary being updated. This can also be used to add more values or replace some values
# to a dictionary by creating a new one with different values. If d1 has keys 1-4 and d2 has
# keys 5-8, then d1 will be updated with keys 1-8 and the values accompanying them.

# %% [markdown]
# ## Section 4 - Automatic Tagging

# %% [markdown]
# **Your Turn:**
# Come up with at least two patterns to improve the performance of the regular expression tagger presented in this chapter (and duplicated below). *Note that section 1 of Chapter 6 describes a way partially automate such work.*
#
# **Your new rules had no impact on tagger performance**

# %%
import re
import nltk
from nltk.corpus import brown
patterns = [
        (r'.*ing$', 'VBG'),               # gerunds
        (r'.*ed$', 'VBD'),                # simple past
        (r'.*es$', 'VBZ'),                # 3rd singular present
        (r'.*ould$', 'MD'),               # modals
        (r'.*\'s$', 'NN$'),               # possessive nouns
        (r'.*s$', 'NNS'),                 # plural nouns
        (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),  # cardinal numbers
        (r'.*', 'NN'),                    # nouns (default)
        (r'/\b([A-Z][a-z]+)\b/','NNP'),   # proper nouns 
        (r'[Tt]o', 'TO'),                 # TO
        (r'/[\W\S]/', 'SYM')]             #Symbols
brown_tagged_sents = brown.tagged_sents(categories='news')
regexp_tagger = nltk.RegexpTagger(patterns)
regexp_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.20326391789486245

# %% [markdown]
# ## Section 5  -  N-Gram Tagging

# %% [markdown]
# ** Exercise:**
# Train a unigram tagger and run it on some new text. Observe that some words are not assigned a tag. Why not?

# %%
from nltk.corpus import brown

brown_tagged_sents = brown.tagged_sents(categories='news')
brown_sents = brown.sents(categories='news')
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)
unigram_tagger.tag(brown_sents[2007])
unigram_tagger.evaluate(brown_tagged_sents)

size = int(len(brown_tagged_sents)*0.9)
train_sents = brown_tagged_sents[:size]
test_sents = brown_tagged_sents[size:]
unigram_tagger = nltk.UnigramTagger(train_sents)
unigram_tagger.evaluate(test_sents)

# input humor category and attempt to test on news category. 
brown_tagged_sents2 = brown.tagged_sents(categories='humor')
brown_sents2 = brown.sents(categories='humor')
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents2)
unigram_tagger.tag(brown_sents[2007])
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'QL'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]
# 0.9349006503968017
# 0.8121200039868434
# [('Various', None),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', None),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', None),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'QL'),
#  ('that', 'CS'),
#  ('entrance', None),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %% [markdown]
# #### Conclusion:
# Testing the same unigram tagger on a new set of text shows us that some words do not have a tag. This is because they are unknown - since the tagger has not seen them before.

# %%
# testing pos tagger - unrelated
from nltk import word_tokenize, pos_tag
text = "The development of the T-72 was a direct result of the introduction of the T-64 tank. The T-64 (Object 432) was a very ambitious project to build a competitive well-armoured tank with a weight of not more than 36 tons. Under the direction of Alexander Morozov in Kharkiv a new design emerged with the hull reduced to the minimum size possible. To do this, the crew was reduced to three soldiers, removing the loader by introducing an automated loading system"
print(pos_tag(word_tokenize(text)))

# %% [markdown]
# **Your Turn:**
# Extend the example below by defining a TrigramTagger called t3, which backs off to t2.

# %%
from nltk.corpus import brown

brown_tagged_sents = brown.tagged_sents(categories='news')
brown_sents = brown.sents(categories='news')
size = int(len(brown_tagged_sents) * 0.9)
train_sents = brown_tagged_sents[:size]
test_sents = brown_tagged_sents[size:]

t0 = nltk.DefaultTagger('NN')
t1 = nltk.UnigramTagger(train_sents, backoff=t0)
t2 = nltk.BigramTagger(train_sents, backoff=t1)
t2.evaluate(test_sents)
t3 = nltk.TrigramTagger(train_sents, backoff=t2)
t3.evaluate(test_sents)
# Out:
# 0.8452108043456593
# 0.843317053722715

# %% [markdown]
# **Exercise:**
# Preprocess the Brown News data by replacing low frequency words with UNK, but leaving the tags untouched. Now train and evaluate a bigram tagger on this data. How much does this help? What is the contribution of the unigram tagger and default tagger now?

# %%
from nltk.corpus import brown
def modify_words(corpus, a):
    nc = []
    for sent in corpus:
        nc.append([(w,a(w,t)) for (w,t) in sent])
    return nc
news_sents = brown.tagged_sents(categories = 'news')
freqD = nltk.FreqDist(brown.words())
most_common = [tag for (tag, __) in freqD.most_common(100)]

def unknown(word,tag):
    if word in most_common:
        return word
    else:
        return 'UNK'
news_sents = modify_words(news_sents, unknown)

size = int(len(news_sents)*0.9)
train = news_sents[:size]
test = news_sents[size:]

defTag = nltk.DefaultTagger('NN')
UniTag = nltk.UnigramTagger(train, backoff=defTag)
UniTag2 = nltk.UnigramTagger(train)
BiTag = nltk.BigramTagger(train, backoff = UniTag)
BiTag2 = nltk.BigramTagger(train)

print('Default tagger performance, alone:', defTag.evaluate(test))
print('Unigram tagger, no backoff:', UniTag2.evaluate(test))
print('Unigram tagger, with backoff to default tagger:', UniTag.evaluate(test))
print('Bigram tagger, no backoff:', BiTag2.evaluate(test))
print('Bigram tagger, with backoff:', BiTag.evaluate(test))
# Out:
# Default tagger performance, alone: 0.0
# Unigram tagger, no backoff: 0.8857769361108343
# Unigram tagger, with backoff to default tagger: 0.8857769361108343
# Bigram tagger, no backoff: 0.11412339280374763
# Bigram tagger, with backoff: 0.8857769361108343

# %% [markdown]
# ### Analysis:
# Bigram tagger displays a performance of 11%. However, the tagger with backoff to unigram tagger shows a result of 88%. This shows us that the default tagger and unigram tagger contribute significantly to the performance the Bigram tagger when using backoff.
#
# Note: Reference and credit for modify_words function: [GitHub](https://github.com/walshbr/nltk/blob/db88a9887751fd65333472a3a15519862a066a08/ch_five/modify.py#L8)

# %% [markdown]
# ## Section 6 - Transformation-Based Tagging

# %% [markdown]
# **Exercise:**
# Run the Brill Tagger demo using the code below.  Select 5 of the useful rules and rewrite them using an English sentence.  For example, if the rule is `NN->VB if Pos:TO@[-1]` the related sentence would be something like, change a noun to a verb if the preceding word is tagged TO.

# %%
from nltk.tbl import demo as brill_tagger
brill_tagger.demo()
# Out:
# Loading tagged data from treebank...
# Read testing data (200 sents/5251 wds)
# Read training data (800 sents/19933 wds)
# Read baseline data (800 sents/19933 wds) [reused the training set]
# Trained baseline tagger
#     Accuracy on test set: 0.8366
# Training tbl tagger...
# TBL train (fast) (seqs: 800; tokens: 19933; tpls: 24; min score: 3; min acc: None)
# Finding initial useful rules...
#     Found 12799 useful rules.
#
#            B      |
#    S   F   r   O  |        Score = Fixed - Broken
#    c   i   o   t  |  R     Fixed = num tags changed incorrect -> correct
#    o   x   k   h  |  u     Broken = num tags changed correct -> incorrect
#    r   e   e   e  |  l     Other = num tags changed incorrect -> incorrect
#    e   d   n   r  |  e
# ------------------+-------------------------------------------------------
#   23  23   0   0  | POS->VBZ if Pos:PRP@[-2,-1]
#   18  19   1   0  | NN->VB if Pos:-NONE-@[-2] & Pos:TO@[-1]
#   14  14   0   0  | VBP->VB if Pos:MD@[-2,-1]
#   12  12   0   0  | VBP->VB if Pos:TO@[-1]
#   11  11   0   0  | VBD->VBN if Pos:VBD@[-1]
#   11  11   0   0  | IN->WDT if Pos:-NONE-@[1] & Pos:VBP@[2]
#   10  11   1   0  | VBN->VBD if Pos:PRP@[-1]
#    9  10   1   0  | VBD->VBN if Pos:VBZ@[-1]
#    8   8   0   0  | NN->VB if Pos:MD@[-1]
#    7   7   0   1  | VB->NN if Pos:DT@[-1]
#    7   7   0   0  | VB->VBP if Pos:PRP@[-1]
#    7   7   0   0  | IN->WDT if Pos:-NONE-@[1] & Pos:VBZ@[2]
#    7   8   1   0  | IN->RB if Word:as@[2]
#    6   6   0   0  | VBD->VBN if Pos:VBP@[-2,-1]
#    6   6   0   1  | IN->WDT if Pos:-NONE-@[1] & Pos:VBD@[2]
#    5   5   0   0  | POS->VBZ if Pos:-NONE-@[-1]
#    5   5   0   0  | VB->VBP if Pos:NNS@[-1]
#    5   5   0   0  | VBD->VBN if Word:be@[-2,-1]
#    4   4   0   0  | POS->VBZ if Pos:``@[-2]
#    4   4   0   0  | VBP->VB if Pos:VBD@[-2,-1]
#    4   6   2   3  | RP->RB if Pos:CD@[1,2]
#    4   4   0   0  | RB->JJ if Pos:DT@[-1] & Pos:NN@[1]
#    4   4   0   0  | NN->VBP if Pos:NNS@[-2] & Pos:RB@[-1]
#    4   5   1   0  | VBN->VBD if Pos:NNP@[-2] & Pos:NNP@[-1]
#    4   4   0   0  | IN->WDT if Pos:-NONE-@[1] & Pos:MD@[2]
#    4   8   4   0  | VBD->VBN if Word:*@[1]
#    4   4   0   0  | JJS->RBS if Word:most@[0] & Word:the@[-1] & Pos:DT@[-1]
#    3   3   0   0  | VBD->VBN if Pos:VBN@[-1]
#    3   4   1   0  | VBN->VB if Pos:TO@[-1]
#    3   4   1   1  | IN->RB if Pos:.@[1]
#    3   3   0   0  | JJ->RB if Pos:VBD@[1]
#    3   3   0   0  | PRP$->PRP if Pos:TO@[1]
#    3   3   0   0  | NN->VBP if Pos:NNS@[-1] & Pos:DT@[1]
#    3   3   0   0  | VBP->VB if Word:n't@[-2,-1]
# Trained tbl tagger in 2.25 seconds
#     Accuracy on test set: 0.8572
# Tagging the test data

# %% [markdown]
# ### Solution here.
# - Change a noun to a verb if the preceding word is tagged as 'MD' or modal.
# - Change a noun to a verb if the preceding two words are NONE and the previous word is tagged as TO.
# - Change a possessive ending to a present tense (third person) of a verb if the preceding words are personal pronouns.
# - Change non third person present tense of a verb to a base verb if the previous word is tagged as TO.
# - Change a past tense of a verb into a past participle of the verb if the previous word is a VBD, or past tense of a verb.
# - Change a preposition into a wh-type determiner if the previous word is classified as a NONE and if the next word in index 2 is a non third person verb in its present tense.
